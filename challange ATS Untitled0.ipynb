# %% [markdown]
# <a href="https://colab.research.google.com/github/nababanmichael061-oss/pemrograman-01/blob/main/challange%20ATS%20Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fungsi untuk menghitung energi (kWh)
def hitung_energi(daya, jam):
    return (daya * jam) / 1000

# Fungsi untuk menghitung biaya listrik
def hitung_biaya(energi, tarif):
    return energi * tarif

# Fungsi menentukan kategori penggunaan
def kategori(energi):
    if energi < 5:
        return "Hemat "
    elif energi < 15:
        return "Sedang "
    else:
        return "Borors "

# ====== PROGRAM UTAMA ======
print("=== Program Perhitungan Biaya Listrik ===")

ulang = True
while ulang:
    tarif = float(input("\nMasukkan tarif listrik per kWh (contoh: 1500): "))
    jumlah = int(input("Masukkan jumlah perangkat listrik: "))

    total_energi = 0
    total_biaya = 0

    # Perulangan for untuk input data perangkat
    for i in range(jumlah):
        print(f"\nPerangkat ke-{i+1}:")
        nama = input("Nama perangkat: ")
        daya = float(input("Daya (Watt): "))
        jam = float(input("Jam pemakaian per hari: "))

        energi = hitung_energi(daya, jam)
        biaya = hitung_biaya(energi, tarif)

        print(f"{nama} → {energi:.2f} kWh | Rp {biaya:,.2f}")

        total_energi += energi
        total_biaya += biaya

    print("\n=== HASIL TOTAL ===")
    print(f"Total Energi : {total_energi:.2f} kWh")
    print(f"Total Biaya  : Rp {total_biaya:,.2f}")
    print(f"Kategori     : {kategori(total_energi)}")

    # Tanya ingin ulang?
    lagi = input("\nHitung lagi? (y/n): ").lower()
    if lagi != "y":
        ulang = False

print("\nTerima kasih telah menggunakan program ini ")
# Out:
# === Program Perhitungan Biaya Listrik ===
#
# Masukkan tarif listrik per kWh (contoh: 1500): 1500
# Masukkan jumlah perangkat listrik: 2
#
# Perangkat ke-1:
# Nama perangkat: Kulkas
# Daya (Watt): 150
# Jam pemakaian per hari: 24
# Kulkas → 3.60 kWh | Rp 5,400.00
#
# Perangkat ke-2:
# Nama perangkat: AC
# Daya (Watt): 800
# Jam pemakaian per hari: 20
# AC → 16.00 kWh | Rp 24,000.00
#
# === HASIL TOTAL ===
# Total Energi : 19.60 kWh
# Total Biaya  : Rp 29,400.00
# Kategori     : Borors
#
# Hitung lagi? (y/n): n
#
# Terima kasih telah menggunakan program ini
